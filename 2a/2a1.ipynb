# %% [markdown]
# # Question 2a1
#
# Train the network using mini-batch gradient descent learning for 1000 epochs. Set the batch size to 128, and learning rate a = 0.001.
#
# a. Plot the (1) training cost, (2) test cost, (3) training accuracy, and (4) test accuracy against learning epochs. One plot for the costs and one plot for the accuracies.
#
# b. For the first two test images, plot the feature maps at both convolution layers (c1 and c2) and pooling layers (s1 and s2) along with the test images.  (In total one image and four feature maps)
#
# Note: A feature map with N channels can be viewed as N grayscale images. Do
# make sure that the pixel values are in the correct range when you plot them.

# %% [markdown]
# # Imports and Setup

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)

# chuanxin
# %cd "../gdrive/My Drive/cz4042_assignment_2/2a"
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/cz4042_assignment_2/2a

# %%
import os
import pickle
import json

import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import tensorflow as tf
from tqdm.keras import TqdmCallback

# %%
seed = 0
np.random.seed(seed)
tf.random.set_seed(seed)

inspect_index = 40

# %% [markdown]
# # Helper functions

# %% [markdown]
# ### load_data(file)
# Used to load in the data

# %%
# Fixed, no need change
def load_data(file):
  with open(file, 'rb') as fo:
    try:
      samples = pickle.load(fo)
    except UnicodeDecodeError:  # python 3.x
      fo.seek(0)
      samples = pickle.load(fo, encoding='latin1')

  data, labels = samples['data'], samples['labels']

  data = np.array(data, dtype=np.float32) / 255
  labels = np.array(labels, dtype=np.int32)
  
  data = data.reshape(len(data), 3, 32, 32).transpose(0, 2, 3, 1)
  return data, labels

# %% [markdown]
# ### make_directories()
# Used to create directories that might not have been made

# %%
# Create folder to store histories and figures
def make_directories():
  if not os.path.exists('./histories'):
      os.mkdir('./histories')
  if not os.path.exists('./figures'):
      os.mkdir('./figures')

# %% [markdown]
# ### history_saver(history, filename, already_json=False)
# Used to save a history object

# %%
# filename like 'history/model_name.json'
def history_saver(history, model_name, already_json=False):
  history_json = {}

  if already_json:
    history_json = history
  else:
    history = history.history
    for key in history.keys():
      history_json[key] = history[key]

  with open('./histories/' + model_name, 'w') as file:
    json.dump(history_json, file)

  print("History saved")

# %% [markdown]
# ### history_loader(filename)
# Used to load in a json history object

# %%
# filename like 'history/model_name.json'
def history_loader(model_name):
  with open('./histories/'+model_name) as json_file:
    history = json.load(json_file)
  print('History loaded')
  
  return history

# %% [markdown]
# ### plot_3_channel_img(np_array):

# %%
def plot_3_channel_img(np_array, inspect_index=None, filename=None):
  if inspect_index == None:
    inspect_index = np.random.randint(len(np_array))

  titles = ['Original', 'Red channel', 'Green channel', 'Blue channel']
  cmaps = [None, plt.cm.Reds_r, plt.cm.Greens_r, plt.cm.Blues_r]

  fig, axes = plt.subplots(1, 4, figsize=(32,8))
  objs = zip(axes, (np_array[inspect_index], *np_array[inspect_index].transpose(2,0,1)), titles, cmaps)

  if filename == None:
    print("index", inspect_index)

  for ax, channel, title, cmap in objs:
    ax.imshow(channel, cmap=cmap)
    ax.set_title(title)
    ax.set_xticks(())
    ax.set_yticks(())
  
  if filename != None:
    fig.savefig(f'./figures/{filename}')

# %% [markdown]
# ### plot_loss(history_json, model_name)
# Plot out loss graph, and also save it

# %%
def plot_loss(history_json, model_name):
  train_loss = history_json['loss']
  test_loss = history_json['val_loss']
  title = 'Model name: ' + model_name + '\nloss against epochs'

  plt.plot(train_loss, label='train')
  plt.plot(test_loss, label='test')
  plt.title(title)
  plt.ylabel('loss')
  plt.xlabel('epochs')
  plt.legend()
  plt.savefig(f'./figures/{model_name}_loss.png')
  
  plt.show()

# %% [markdown]
# ### plot_acc(history_json, model_name)
# Plot out accuracy graph, and also save it

# %%
def plot_acc(history_json, model_name):
  train_acc = history_json['accuracy']
  test_acc = history_json['val_accuracy']
  title = 'Model name: ' + model_name + '\naccuracy against epochs'

  plt.plot(train_acc, label='train')
  plt.plot(test_acc, label='test')
  plt.title(title)
  plt.ylabel('accuracy')
  plt.xlabel('epochs')
  plt.legend()
  plt.savefig(f'./figures/{model_name}_accuracy.png')
  
  plt.show()

# %% [markdown]
# ### plot_activations(model, model_name, x_data, x_data_name)
# Get the intermediate activations for a single x_data (one item in x_train or x_test)

# %%
def plot_activations(model, model_name, x_data, x_data_name):
  plot_3_channel_img(x_data, filename=f'{model_name}_{x_data_name}_source.png')

  layer_outputs = [layer.output for layer in model.layers]
  activation_model = tf.keras.Model(inputs=model.input, outputs=layer_outputs) # Creates a model that will return these outputs, given the model input
  activations = activation_model.predict(x_data) 

  activation_layer_names = ['conv1', 'max1', 'conv2', 'max2']  
  activations = activations[:4]

  images_per_row = 10
  
  for layer_name, layer_activation in zip(activation_layer_names, activations): # Displays the feature maps
    n_features = layer_activation.shape[-1] # Number of features in the feature map
    size = layer_activation.shape[1] #The feature map has shape (1, size, size, n_features).
    n_cols = n_features // images_per_row # Tiles the activation channels in this matrix
    display_grid = np.zeros((size * n_cols, images_per_row * size))

    for col in range(n_cols): # Tiles each filter into a big horizontal grid
      for row in range(images_per_row):
        channel_image = layer_activation[0, :, :, col * images_per_row + row]
        channel_image -= channel_image.mean() # Post-processes the feature to make it visually palatable
        channel_image /= channel_image.std()
        channel_image *= 64
        channel_image += 128
        channel_image = np.clip(channel_image, 0, 255).astype('uint8')
        display_grid[col * size : (col + 1) * size, row * size : (row + 1) * size] = channel_image # Displays the grid 
        
    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1],
                        scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.axis('off')
    plt.imshow(display_grid, aspect='auto', cmap='viridis')
    plt.savefig(f'./figures/{model_name}_{x_data_name}_{layer_name}.png')
    plt.show()

# %% [markdown]
# # 2a1 - conv1 = 50 channels, conv2 = 60 channels

# %%
# Training and test
make_directories()
x_train, y_train = load_data('data_batch_1')
x_test, y_test = load_data('test_batch_trim')

# %% [markdown]
# ### make_model(num_ch_c1, num_ch_c2, use_dropout)
# Creates a CNN model that has number of channels for the Conv2D layer specified, and also dropout, if needed

# %%
def make_model(num_ch_c1, num_ch_c2, use_dropout):
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(32, 32, 3), name='input'))
    model.add(tf.keras.layers.Conv2D(num_ch_c1, 9, activation='relu', input_shape=(None, None, 3), padding='valid', name='conv1'))
    model.add(tf.keras.layers.MaxPool2D(pool_size=(2,2), strides=2, padding='valid', name='max1'))
    model.add(tf.keras.layers.Conv2D(num_ch_c2, 5, activation='relu', input_shape=(None, None, 3), padding='valid', name='conv2'))
    model.add(tf.keras.layers.MaxPool2D(pool_size=(2,2), strides=2, padding='valid', name='max2'))
    model.add(tf.keras.layers.Flatten(name='flatten'))
    if use_dropout:
      model.add(tf.keras.layers.Dropout(rate=0.5, name='dropout1'))
    model.add(tf.keras.layers.Dense(300, use_bias=True, name='dense1'))
    if use_dropout:
      model.add(tf.keras.layers.Dropout(rate=0.5, name='dropout2'))
    model.add(tf.keras.layers.Dense(10, use_bias=True, input_shape=(300,), name='dense2'))  # Here no softmax because we have combined it with the loss    
    
    return model

# %% [markdown]
# ### set_model_parameters(optimizer_, model_name)
# Select the optimizer and give the model a name that will be used to save it.
#
# Returns `epochs, batch_size, loss, callbacks, optimizer, model_name`

# %%
def set_model_parameters(optimizer_, model_name):
  # fixed 
  epochs = 1000  
  batch_size = 128  
  learning_rate = 0.001 
  loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
  callbacks = [TqdmCallback(verbose=1)]


  if optimizer_ == 'SGD':
    optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)
  elif optimizer_ == 'SGD-momentum':
    optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.1)
  elif optimizer_ == 'RMSProp': 
    optimizer = tf.keras.optimizers.RMSprop(learning_rate=learning_rate)
  elif optimizer_ == 'Adam': 
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
  else:
    raise NotImplementedError(f'You do not need to handle [{optimizer_}] in this project.')

  return epochs, batch_size, loss, callbacks, optimizer, model_name

# %% [markdown]
# ### Hyperparameters

# %%
num_ch_c1 = 50
num_ch_c2 = 60

# %%
model = make_model(num_ch_c1, num_ch_c2, False)
epochs, batch_size, loss, callbacks, optimizer, model_name = set_model_parameters('SGD', f'q1_model_{num_ch_c1}_{num_ch_c2}')

model.compile(optimizer=optimizer, loss=loss, metrics='accuracy')

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_data=(x_test, y_test))

history_saver(history, model_name)
history_json = history_loader(model_name)
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Epoch 1/1000
# 79/79 [==============================] - 1s 10ms/step - loss: 2.3054 - accuracy: 0.1013 - val_loss: 2.2982 - val_accuracy: 0.1120
# Epoch 2/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.2938 - accuracy: 0.1187 - val_loss: 2.2904 - val_accuracy: 0.1140
# Epoch 3/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.2872 - accuracy: 0.1197 - val_loss: 2.2843 - val_accuracy: 0.1180
# Epoch 4/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.2812 - accuracy: 0.1259 - val_loss: 2.2779 - val_accuracy: 0.1355
# Epoch 5/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.2743 - accuracy: 0.1384 - val_loss: 2.2701 - val_accuracy: 0.1470
# Epoch 6/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.2660 - accuracy: 0.1511 - val_loss: 2.2615 - val_accuracy: 0.1685
# Epoch 7/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.2570 - accuracy: 0.1636 - val_loss: 2.2521 - val_accuracy: 0.1820
# Epoch 8/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.2470 - accuracy: 0.1768 - val_loss: 2.2413 - val_accuracy: 0.1905
# Epoch 9/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.2355 - accuracy: 0.1865 - val_loss: 2.2289 - val_accuracy: 0.1955
# Epoch 10/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.2225 - accuracy: 0.2008 - val_loss: 2.2156 - val_accuracy: 0.2095
# Epoch 11/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.2078 - accuracy: 0.2061 - val_loss: 2.1990 - val_accuracy: 0.2185
# Epoch 12/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.1913 - accuracy: 0.2236 - val_loss: 2.1816 - val_accuracy: 0.2150
# Epoch 13/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.1732 - accuracy: 0.2249 - val_loss: 2.1633 - val_accuracy: 0.2255
# Epoch 14/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.1542 - accuracy: 0.2365 - val_loss: 2.1433 - val_accuracy: 0.2285
# Epoch 15/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.1354 - accuracy: 0.2418 - val_loss: 2.1248 - val_accuracy: 0.2400
# Epoch 16/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.1166 - accuracy: 0.2479 - val_loss: 2.1057 - val_accuracy: 0.2415
# Epoch 17/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.0992 - accuracy: 0.2541 - val_loss: 2.0886 - val_accuracy: 0.2535
# Epoch 18/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.0826 - accuracy: 0.2552 - val_loss: 2.0746 - val_accuracy: 0.2520
# Epoch 19/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.0679 - accuracy: 0.2663 - val_loss: 2.0612 - val_accuracy: 0.2540
# Epoch 20/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.0543 - accuracy: 0.2671 - val_loss: 2.0478 - val_accuracy: 0.2605
# Epoch 21/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 2.0425 - accuracy: 0.2740 - val_loss: 2.0358 - val_accuracy: 0.2565
# Epoch 22/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.0314 - accuracy: 0.2720 - val_loss: 2.0458 - val_accuracy: 0.2360
# Epoch 23/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.0227 - accuracy: 0.2752 - val_loss: 2.0210 - val_accuracy: 0.2595
# Epoch 24/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.0136 - accuracy: 0.2775 - val_loss: 2.0109 - val_accuracy: 0.2655
# Epoch 25/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 2.0060 - accuracy: 0.2862 - val_loss: 2.0371 - val_accuracy: 0.2555
# Epoch 26/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.9994 - accuracy: 0.2857 - val_loss: 1.9951 - val_accuracy: 0.2855
# Epoch 27/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.9927 - accuracy: 0.2856 - val_loss: 1.9891 - val_accuracy: 0.2755
# Epoch 28/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.9864 - accuracy: 0.2900 - val_loss: 1.9856 - val_accuracy: 0.2885
# Epoch 29/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.9814 - accuracy: 0.2901 - val_loss: 1.9853 - val_accuracy: 0.2765
# Epoch 30/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.9754 - accuracy: 0.2940 - val_loss: 1.9958 - val_accuracy: 0.2775
# Epoch 31/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.9705 - accuracy: 0.2942 - val_loss: 1.9699 - val_accuracy: 0.2860
# Epoch 32/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.9657 - accuracy: 0.2947 - val_loss: 1.9669 - val_accuracy: 0.2895
# Epoch 33/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.9610 - accuracy: 0.2964 - val_loss: 1.9570 - val_accuracy: 0.3010
# Epoch 34/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.9550 - accuracy: 0.3005 - val_loss: 1.9519 - val_accuracy: 0.2915
# Epoch 35/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.9502 - accuracy: 0.3062 - val_loss: 1.9538 - val_accuracy: 0.2915
# Epoch 36/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.9454 - accuracy: 0.3067 - val_loss: 1.9573 - val_accuracy: 0.2960
# Epoch 37/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.9407 - accuracy: 0.3070 - val_loss: 1.9574 - val_accuracy: 0.2945
# Epoch 38/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.9366 - accuracy: 0.3082 - val_loss: 1.9378 - val_accuracy: 0.3020
# Epoch 39/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.9317 - accuracy: 0.3119 - val_loss: 1.9352 - val_accuracy: 0.2895
# Epoch 40/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.9270 - accuracy: 0.3124 - val_loss: 1.9494 - val_accuracy: 0.2975
# Epoch 41/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.9230 - accuracy: 0.3168 - val_loss: 1.9300 - val_accuracy: 0.2995
# Epoch 42/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.9183 - accuracy: 0.3126 - val_loss: 1.9196 - val_accuracy: 0.3030
# Epoch 43/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.9133 - accuracy: 0.3187 - val_loss: 1.9172 - val_accuracy: 0.3115
# Epoch 44/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.9093 - accuracy: 0.3204 - val_loss: 1.9146 - val_accuracy: 0.3090
# Epoch 45/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.9039 - accuracy: 0.3214 - val_loss: 1.9190 - val_accuracy: 0.3080
# Epoch 46/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1
1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3990 - accuracy: 0.5085 - val_loss: 1.5525 - val_accuracy: 0.4430
# Epoch 232/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.4010 - accuracy: 0.5063 - val_loss: 1.5613 - val_accuracy: 0.4370
# Epoch 233/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3958 - accuracy: 0.5111 - val_loss: 1.5560 - val_accuracy: 0.4480
# Epoch 234/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3950 - accuracy: 0.5082 - val_loss: 1.5936 - val_accuracy: 0.4445
# Epoch 235/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3931 - accuracy: 0.5129 - val_loss: 1.5513 - val_accuracy: 0.4440
# Epoch 236/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3933 - accuracy: 0.5081 - val_loss: 1.4734 - val_accuracy: 0.4775
# Epoch 237/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 1.3883 - accuracy: 0.5127 - val_loss: 1.4937 - val_accuracy: 0.4660
# Epoch 238/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.3897 - accuracy: 0.5106 - val_loss: 1.5011 - val_accuracy: 0.4595
# Epoch 239/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.3878 - accuracy: 0.5121 - val_loss: 1.4459 - val_accuracy: 0.4895
# Epoch 240/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3830 - accuracy: 0.5119 - val_loss: 1.5613 - val_accuracy: 0.4365
# Epoch 241/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.3840 - accuracy: 0.5099 - val_loss: 1.4664 - val_accuracy: 0.4825
# Epoch 242/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3817 - accuracy: 0.5118 - val_loss: 1.7083 - val_accuracy: 0.4140
# Epoch 243/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.3862 - accuracy: 0.5131 - val_loss: 1.4383 - val_accuracy: 0.4810
# Epoch 244/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3844 - accuracy: 0.5168 - val_loss: 1.6152 - val_accuracy: 0.4450
# Epoch 245/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.3825 - accuracy: 0.5156 - val_loss: 1.4679 - val_accuracy: 0.4750
# Epoch 246/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3809 - accuracy: 0.5129 - val_loss: 1.4622 - val_accuracy: 0.4835
# Epoch 247/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 1.3793 - accuracy: 0.5159 - val_loss: 1.4947 - val_accuracy: 0.4640
# Epoch 248/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3751 - accuracy: 0.5151 - val_loss: 1.5323 - val_accuracy: 0.4615
# Epoch 249/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3791 - accuracy: 0.5118 - val_loss: 1.6499 - val_accuracy: 0.4485
# Epoch 250/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3772 - accuracy: 0.5147 - val_loss: 1.5676 - val_accuracy: 0.4500
# Epoch 251/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3729 - accuracy: 0.5164 - val_loss: 1.4912 - val_accuracy: 0.4770
# Epoch 252/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3728 - accuracy: 0.5144 - val_loss: 1.4829 - val_accuracy: 0.4685
# Epoch 253/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3685 - accuracy: 0.5167 - val_loss: 1.5205 - val_accuracy: 0.4560
# Epoch 254/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.3708 - accuracy: 0.5174 - val_loss: 1.5188 - val_accuracy: 0.4690
# Epoch 255/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.3725 - accuracy: 0.5153 - val_loss: 1.4484 - val_accuracy: 0.4860
# Epoch 256/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 1.3657 - accuracy: 0.5229 - val_loss: 1.4452 - val_accuracy: 0.4855
# Epoch 257/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 1.3677 - accuracy: 0.5209 - val_loss: 1.5445 - val_accuracy: 0.4830
# Epoch 258/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.3665 - accuracy: 0.5205 - val_loss: 1.4597 - val_accuracy: 0.4875
# Epoch 259/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3610 - accuracy: 0.5227 - val_loss: 1.5964 - val_accuracy: 0.4490
# Epoch 260/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3627 - accuracy: 0.5217 - val_loss: 1.4325 - val_accuracy: 0.4890
# Epoch 261/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.3599 - accuracy: 0.5222 - val_loss: 1.4845 - val_accuracy: 0.4780
# Epoch 262/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.
1000
# 79/79 [==============================] - 1s 7ms/step - loss: 1.3203 - accuracy: 0.5362 - val_loss: 1.4547 - val_accuracy: 0.4825
# Epoch 294/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.3215 - accuracy: 0.5362 - val_loss: 1.4618 - val_accuracy: 0.4680
# Epoch 295/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.3206 - accuracy: 0.5319 - val_loss: 1.4414 - val_accuracy: 0.4985
# Epoch 296/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 1.3177 - accuracy: 0.5361 - val_loss: 1.5852 - val_accuracy: 0.4580
# Epoch 297/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3190 - accuracy: 0.5361 - val_loss: 1.4633 - val_accuracy: 0.4710
# Epoch 298/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3131 - accuracy: 0.5352 - val_loss: 1.3964 - val_accuracy: 0.5000
# Epoch 299/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.3124 - accuracy: 0.5376 - val_loss: 1.4690 - val_accuracy: 0.4835
# Epoch 300/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3134 - accuracy: 0.5372 - val_loss: 1.6074 - val_accuracy: 0.4510
# Epoch 301/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.3159 - accuracy: 0.5367 - val_loss: 1.4574 - val_accuracy: 0.4800
# Epoch 302/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3103 - accuracy: 0.5395 - val_loss: 1.4020 - val_accuracy: 0.5035
# Epoch 303/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3120 - accuracy: 0.5411 - val_loss: 1.3965 - val_accuracy: 0.5110
# Epoch 304/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.3091 - accuracy: 0.5422 - val_loss: 1.4332 - val_accuracy: 0.5015
# Epoch 305/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3079 - accuracy: 0.5382 - val_loss: 1.4638 - val_accuracy: 0.4835
# Epoch 306/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3059 - accuracy: 0.5427 - val_loss: 1.4310 - val_accuracy: 0.4970
# Epoch 307/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.3021 - accuracy: 0.5451 - val_loss: 1.5242 - val_accuracy: 0.4600
# Epoch 308/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 1.3048 - accuracy: 0.5395 - val_loss: 1.4288 - val_accuracy: 0.4820
# Epoch 309/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.3039 - accuracy: 0.5400 - val_loss: 1.6232 - val_accuracy: 0.4400
# Epoch 310/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 1.3050 - accuracy: 0.5421 - val_loss: 1.4193 - val_accuracy: 0.5030
# Epoch 311/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.3021 - accuracy: 0.5434 - val_loss: 1.4252 - val_accuracy: 0.4890
# Epoch 312/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 1.2974 - accuracy: 0.5462 - val_loss: 1.3980 - val_accuracy: 0.5015
# Epoch 313/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.2988 - accuracy: 0.5445 - val_loss: 1.4498 - val_accuracy: 0.5005
# Epoch 314/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.3010 - accuracy: 0.5415 - val_loss: 1.5308 - val_accuracy: 0.4695
# Epoch 315/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 1.2946 - accuracy: 0.5450 - val_loss: 1.4287 - val_accuracy: 0.5105
# Epoch 316/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.2952 - accuracy: 0.5474 - val_loss: 1.4601 - val_accuracy: 0.5080
# Epoch 317/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 1.2958 - accuracy: 0.5446 - val_loss: 1.4228 - val_accuracy: 0.5010
# Epoch 318/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.2946 - accuracy: 0.5447 - val_loss: 1.5818 - val_accuracy: 0.4215
# Epoch 319/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.2956 - accuracy: 0.5458 - val_loss: 1.4156 - val_accuracy: 0.4810
# Epoch 320/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 1.2892 - accuracy: 0.5454 - val_loss: 1.3851 - val_accuracy: 0.5060
# Epoch 321/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.2893 - accuracy: 0.5500 - val_loss: 1.3866 - val_accuracy: 0.5100
# Epoch 322/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.2905 - accuracy: 0.5464 - val_loss: 1.4083 - val_accuracy: 0.5075
# Epoch 323/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.2855 - accuracy: 0.5450 - val_loss: 1.4289 - val_accuracy: 0.4915
# Epoch 324/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 1.2854 - accuracy: 0.5452 - val_loss: 1.4660 - val_accuracy: 0.4705
# Epoch 325/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.2875 - accuracy: 0.5483 - val_loss: 1.5194 - val_accuracy: 0.4540
# Epoch 326/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.2828 - accuracy: 0.5488 - val_loss: 1.4616 - val_accuracy: 0.4930
# Epoch 327/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.2820 - accuracy: 0.5499 - val_loss: 1.4362 - val_accuracy: 0.4860
# Epoch 328/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 1.2848 - accuracy: 0.5450 - val_loss: 1.5816 - val_accuracy: 0.4350
# Epoch 329/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.2803 - accuracy: 0.5511 - val_loss: 1.4583 - val_accuracy: 0.4750
# Epoch 330/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.2793 - accuracy: 0.5547 - val_loss: 1.3765 - val_accuracy: 0.5160
# Epoch 331/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.2812 - accuracy: 0.5517 - val_loss: 1.4801 - val_accuracy: 0.4705
# Epoch 332/1000
# 79/79 [==============================] - 0s 6ms/step - loss: 1.2812 - accuracy: 0.5544 - val_loss: 1.4059 - val_accuracy: 0.4960
# Epoch 333/1000
# ...
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7751 - accuracy: 0.7424 - val_loss: 1.3754 - val_accuracy: 0.5625
# Epoch 891/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7685 - accuracy: 0.7453 - val_loss: 1.7183 - val_accuracy: 0.4760
# Epoch 892/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7714 - accuracy: 0.7439 - val_loss: 1.8034 - val_accuracy: 0.4750
# Epoch 893/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7738 - accuracy: 0.7417 - val_loss: 1.2779 - val_accuracy: 0.5800
# Epoch 894/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7682 - accuracy: 0.7453 - val_loss: 1.3409 - val_accuracy: 0.5690
# Epoch 895/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7641 - accuracy: 0.7459 - val_loss: 1.3849 - val_accuracy: 0.5550
# Epoch 896/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7670 - accuracy: 0.7446 - val_loss: 1.5068 - val_accuracy: 0.4980
# Epoch 897/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7658 - accuracy: 0.7465 - val_loss: 1.2849 - val_accuracy: 0.5775
# Epoch 898/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7607 - accuracy: 0.7431 - val_loss: 1.2973 - val_accuracy: 0.5620
# Epoch 899/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7657 - accuracy: 0.7447 - val_loss: 1.5152 - val_accuracy: 0.5125
# Epoch 900/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7633 - accuracy: 0.7461 - val_loss: 1.3112 - val_accuracy: 0.5740
# Epoch 901/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7615 - accuracy: 0.7448 - val_loss: 1.3496 - val_accuracy: 0.5640
# Epoch 902/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7655 - accuracy: 0.7435 - val_loss: 1.3111 - val_accuracy: 0.5765
# Epoch 903/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7592 - accuracy: 0.7458 - val_loss: 1.3588 - val_accuracy: 0.5615
# Epoch 904/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7601 - accuracy: 0.7480 - val_loss: 1.3242 - val_accuracy: 0.5755
# Epoch 905/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7582 - accuracy: 0.7483 - val_loss: 1.4455 - val_accuracy: 0.5550
# Epoch 906/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7604 - accuracy: 0.7433 - val_loss: 1.3549 - val_accuracy: 0.5600
# Epoch 907/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7603 - accuracy: 0.7472 - val_loss: 1.2957 - val_accuracy: 0.5665
# Epoch 908/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7534 - accuracy: 0.7517 - val_loss: 1.5560 - val_accuracy: 0.5290
# Epoch 909/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7566 - accuracy: 0.7535 - val_loss: 1.3520 - val_accuracy: 0.5675
# Epoch 910/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7544 - accuracy: 0.7481 - val_loss: 1.3298 - val_accuracy: 0.5520
# Epoch 911/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7575 - accuracy: 0.7484 - val_loss: 1.3352 - val_accuracy: 0.5605
# Epoch 912/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7606 - accuracy: 0.7444 - val_loss: 1.3428 - val_accuracy: 0.5580
# Epoch 913/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7539 - accuracy: 0.7475 - val_loss: 1.3693 - val_accuracy: 0.5530
# Epoch 914/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7497 - accuracy: 0.7501 - val_loss: 1.5055 - val_accuracy: 0.5255
# Epoch 915/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7503 - accuracy: 0.7526 - val_loss: 1.4156 - val_accuracy: 0.5560
# Epoch 916/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7529 - accuracy: 0.7501 - val_loss: 1.4911 - val_accuracy: 0.5120
# Epoch 917/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7517 - accuracy: 0.7469 - val_loss: 1.3507 - val_accuracy: 0.5490
# Epoch 918/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7498 - accuracy: 0.7500 - val_loss: 1.4963 - val_accuracy: 0.5145
# Epoch 919/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7534 - accuracy: 0.7485 - val_loss: 1.5287 - val_accuracy: 0.5170
# Epoch 920/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7561 - accuracy: 0.7485 - val_loss: 1.4672 - val_accuracy: 0.5460
# Epoch 921/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7505 - accuracy: 0.7539 - val_loss: 1.5008 - val_accuracy: 0.5255
# Epoch 922/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7490 - accuracy: 0.7504 - val_loss: 1.5399 - val_accuracy: 0.5135
# Epoch 923/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7464 - accuracy: 0.7494 - val_loss: 1.3940 - val_accuracy: 0.5385
# Epoch 924/1000
# 79/79 [==============================] - 1s 8ms/step - loss: 0.7402 - accuracy: 0.7550 - val_loss: 1.3807 - val_accuracy: 0.5545
# Epoch 925/1000
# 79/79 [==============================] - 1s 8ms/step - loss: 0.7426 - accuracy: 0.7515 - val_loss: 1.3490 - val_accuracy: 0.5675
# Epoch 926/1000
# 79/79 [==============================] - 1s 8ms/step - loss: 0.7433 - accuracy: 0.7513 - val_loss: 1.4638 - val_accuracy: 0.5250
# Epoch 927/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7422 - accuracy: 0.7513 - val_loss: 1.3734 - val_accuracy: 0.5570
# Epoch 928/1000
# 79/79 [==============================] - 1s 8ms/step - loss: 0.7379 - accuracy: 0.7552 - val_loss: 1.3732 - val_accuracy: 0.5565
# Epoch 929/1000
# 79/79 [==============================] - 1s 8ms/step - loss: 0.7369 - accuracy: 0.7552 - val_loss: 1.3991 - val_accuracy: 0.5425
# Epoch 930/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7385 - accuracy: 0.7539 - val_loss: 1.4079 - val_accuracy: 0.5485
# Epoch 931/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7381 - accuracy: 0.7557 - val_loss: 1.5761 - val_accuracy: 0.5155
# Epoch 932/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7383 - accuracy: 0.7509 - val_loss: 1.3752 - val_accuracy: 0.5630
# Epoch 933/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7351 - accuracy: 0.7571 - val_loss: 1.4031 - val_accuracy: 0.5515
# Epoch 934/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7373 - accuracy: 0.7559 - val_loss: 1.6533 - val_accuracy: 0.5075
# Epoch 935/1000
# 79/79 [==============================] - 1s 8ms/step - loss: 0.7402 - accuracy: 0.7520 - val_loss: 1.3729 - val_accuracy: 0.5580
# Epoch 936/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7347 - accuracy: 0.7567 - val_loss: 1.3968 - val_accuracy: 0.5540
# Epoch 937/1000
# 79/79 [==============================] - 1s 8ms/step - loss: 0.7325 - accuracy: 0.7574 - val_loss: 1.3087 - val_accuracy: 0.5795
# Epoch 938/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7300 - accuracy: 0.7592 - val_loss: 1.3790 - val_accuracy: 0.5665
# Epoch 939/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7320 - accuracy: 0.7571 - val_loss: 1.3597 - val_accuracy: 0.5615
# Epoch 940/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7298 - accuracy: 0.7595 - val_loss: 1.5002 - val_accuracy: 0.5230
# Epoch 941/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7263 - accuracy: 0.7577 - val_loss: 1.3407 - val_accuracy: 0.5685
# Epoch 942/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7263 - accuracy: 0.7595 - val_loss: 1.3775 - val_accuracy: 0.5500
# Epoch 943/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7345 - accuracy: 0.7585 - val_loss: 1.3493 - val_accuracy: 0.5555
# Epoch 944/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7275 - accuracy: 0.7596 - val_loss: 1.3563 - val_accuracy: 0.5630
# Epoch 945/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7292 - accuracy: 0.7565 - val_loss: 1.3673 - val_accuracy: 0.5555
# Epoch 946/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7236 - accuracy: 0.7588 - val_loss: 1.6636 - val_accuracy: 0.4925
# Epoch 947/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7327 - accuracy: 0.7544 - val_loss: 1.3206 - val_accuracy: 0.5680
# Epoch 948/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7230 - accuracy: 0.7573 - val_loss: 1.3941 - val_accuracy: 0.5660
# Epoch 949/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7257 - accuracy: 0.7549 - val_loss: 1.3582 - val_accuracy: 0.5715
# Epoch 950/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7197 - accuracy: 0.7595 - val_loss: 1.4628 - val_accuracy: 0.5425
# Epoch 951/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7230 - accuracy: 0.7598 - val_loss: 1.3839 - val_accuracy: 0.5565
# Epoch 952/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7288 - accuracy: 0.7566 - val_loss: 1.9540 - val_accuracy: 0.4490
# Epoch 953/1000
# 79/79 [==============================] - 1s 6ms/step - loss: 0.7263 - accuracy: 0.7601 - val_loss: 1.3958 - val_accuracy: 0.5485
# Epoch 954/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7208 - accuracy: 0.7612 - val_loss: 1.3063 - val_accuracy: 0.5745
# Epoch 955/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7145 - accuracy: 0.7632 - val_loss: 1.5579 - val_accuracy: 0.5285
# Epoch 956/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7203 - accuracy: 0.7587 - val_loss: 1.3569 - val_accuracy: 0.5545
# Epoch 957/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7140 - accuracy: 0.7646 - val_loss: 1.3844 - val_accuracy: 0.5430
# Epoch 958/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7173 - accuracy: 0.7637 - val_loss: 1.3480 - val_accuracy: 0.5655
# Epoch 959/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7126 - accuracy: 0.7629 - val_loss: 1.5562 - val_accuracy: 0.5145
# Epoch 960/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7128 - accuracy: 0.7644 - val_loss: 1.3122 - val_accuracy: 0.5825
# Epoch 961/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7119 - accuracy: 0.7653 - val_loss: 1.4063 - val_accuracy: 0.5450
# Epoch 962/1000
# 79/79 [==============================] - 1s 8ms/step - loss: 0.7134 - accuracy: 0.7642 - val_loss: 1.4179 - val_accuracy: 0.5460
# Epoch 963/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7134 - accuracy: 0.7591 - val_loss: 1.3053 - val_accuracy: 0.5785
# Epoch 964/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7102 - accuracy: 0.7639 - val_loss: 2.0131 - val_accuracy: 0.4140
# Epoch 965/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7187 - accuracy: 0.7585 - val_loss: 1.3041 - val_accuracy: 0.5825
# Epoch 966/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7092 - accuracy: 0.7675 - val_loss: 1.6987 - val_accuracy: 0.5165
# Epoch 967/1000
# 79/79 [==============================] - 1s 8ms/step - loss: 0.7169 - accuracy: 0.7595 - val_loss: 1.4586 - val_accuracy: 0.5335
# Epoch 968/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7091 - accuracy: 0.7649 - val_loss: 1.3822 - val_accuracy: 0.5505
# Epoch 969/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7071 - accuracy: 0.7671 - val_loss: 1.3379 - val_accuracy: 0.5600
# Epoch 970/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7102 - accuracy: 0.7639 - val_loss: 1.4908 - val_accuracy: 0.5320
# Epoch 971/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7057 - accuracy: 0.7674 - val_loss: 1.3565 - val_accuracy: 0.5700
# Epoch 972/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7024 - accuracy: 0.7669 - val_loss: 1.6829 - val_accuracy: 0.4700
# Epoch 973/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7139 - accuracy: 0.7632 - val_loss: 1.3862 - val_accuracy: 0.5605
# Epoch 974/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7091 - accuracy: 0.7648 - val_loss: 1.4472 - val_accuracy: 0.5445
# Epoch 975/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7007 - accuracy: 0.7713 - val_loss: 1.5098 - val_accuracy: 0.5275
# Epoch 976/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7060 - accuracy: 0.7627 - val_loss: 1.3152 - val_accuracy: 0.5835
# Epoch 977/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.6986 - accuracy: 0.7699 - val_loss: 1.4326 - val_accuracy: 0.5580
# Epoch 978/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7028 - accuracy: 0.7671 - val_loss: 1.4599 - val_accuracy: 0.5450
# Epoch 979/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7012 - accuracy: 0.7674 - val_loss: 1.3267 - val_accuracy: 0.5780
# Epoch 980/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.6990 - accuracy: 0.7690 - val_loss: 1.4451 - val_accuracy: 0.5350
# Epoch 981/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7091 - accuracy: 0.7660 - val_loss: 1.3250 - val_accuracy: 0.5760
# Epoch 982/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7013 - accuracy: 0.7664 - val_loss: 1.4836 - val_accuracy: 0.5370
# Epoch 983/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.6955 - accuracy: 0.7705 - val_loss: 1.6946 - val_accuracy: 0.5045
# Epoch 984/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.7015 - accuracy: 0.7663 - val_loss: 1.4028 - val_accuracy: 0.5525
# Epoch 985/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.6954 - accuracy: 0.7717 - val_loss: 1.5412 - val_accuracy: 0.5080
# Epoch 986/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.6961 - accuracy: 0.7696 - val_loss: 1.4692 - val_accuracy: 0.5490
# Epoch 987/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.6934 - accuracy: 0.7693 - val_loss: 1.3600 - val_accuracy: 0.5640
# Epoch 988/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.6929 - accuracy: 0.7714 - val_loss: 1.4421 - val_accuracy: 0.5460
# Epoch 989/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.6922 - accuracy: 0.7730 - val_loss: 1.3149 - val_accuracy: 0.5725
# Epoch 990/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.6919 - accuracy: 0.7727 - val_loss: 1.4540 - val_accuracy: 0.5465
# Epoch 991/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.6875 - accuracy: 0.7745 - val_loss: 1.3848 - val_accuracy: 0.5490
# Epoch 992/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.6902 - accuracy: 0.7708 - val_loss: 1.3712 - val_accuracy: 0.5755
# Epoch 993/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.6875 - accuracy: 0.7726 - val_loss: 1.6322 - val_accuracy: 0.5005
# Epoch 994/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.6961 - accuracy: 0.7690 - val_loss: 1.3564 - val_accuracy: 0.5610
# Epoch 995/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.6924 - accuracy: 0.7690 - val_loss: 1.3561 - val_accuracy: 0.5675
# Epoch 996/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.6898 - accuracy: 0.7720 - val_loss: 1.4551 - val_accuracy: 0.5550
# Epoch 997/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.6864 - accuracy: 0.7720 - val_loss: 1.3072 - val_accuracy: 0.5845
# Epoch 998/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.6822 - accuracy: 0.7761 - val_loss: 1.6625 - val_accuracy: 0.5055
# Epoch 999/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.6853 - accuracy: 0.7746 - val_loss: 1.6272 - val_accuracy: 0.5110
# Epoch 1000/1000
# 79/79 [==============================] - 1s 7ms/step - loss: 0.6873 - accuracy: 0.7720 - val_loss: 1.4525 - val_accuracy: 0.5475
#
# History saved
# History loaded

# %%
plot_acc(history_json, model_name)
plot_loss(history_json, model_name)

# %%
for i in range(2):
  print("-"*100)
  print("x_test", i)
  x_data = np.expand_dims(x_test[i], axis=0) 
  plot_activations(model, model_name, x_data[:2], 'xtest' + str(i))
  print("-"*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# x_test 0
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in true_divide
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# x_test 1
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Conclusion
